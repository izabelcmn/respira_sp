# %% [markdown]
# #  XGBoost  Training(2013—2019) - Respira SP
#
# Este notebook dá continuidade à preparação dos dados, utilizando os datasets supervisionados gerados anteriormente para treinar, regularizar e avaliar modelos XGBoost na previsão de PM2.5 24 horas à frente.
#
# Foram comparadas três estratégias de pré-processamento para tratamento de gaps, além de diferentes configurações do XGBoost: modelo inicial, modelo regularizado, modelo com novas features temporais e modelo regularizado com novas features temporais.
#
# ## O que foi feito
#
# - Carregamento dos datasets supervisionados referentes às três estratégias de pré-processamento;
# - Remoção da coluna `MP2.5` original para evitar seu uso direto como feature no modelo;
# - Definição das features utilizadas no treinamento e do target `target_24h`;
# - Realização do `split temporal` dos dados:
#     - Treino: dados ***anteriores a 2018***;
#     - Validação: ***dados de 2018***;
#     - Teste: ***dados de 2019***;
# - Criação de uma pipeline com SimpleImputer, garantindo que o ajuste do imputer seja feito apenas nos dados de treino;
# - Transformação dos dados de validação e teste utilizando apenas o objeto ajustado no treino, evitando data leakage;
# - Treinamento de um baseline simples baseado em `PM2.5_lag_24h`;
# - Treinamento inicial do modelo ***XGBoost*** para cada estratégia de pré-processamento;
# - Avaliação dos modelos com `MAE, RMSE e R²`;
# - Comparação entre `baseline` e `XGBoost` no conjunto de validação;
# - Avaliação final do `XGBoost` no conjunto de teste;
# - Análise de `feature importance`;
# - Análise de `desempenho por split`;
# - Construção de `learning curves` para investigar possíveis sinais de overfitting, underfitting ou data leakage.
# - Realização de `GridSearchCV` com `TimeSeriesSplit` para buscar configurações mais regularizadas;
# - Treinamento de modelos `XGBoost` regularizados usando os melhores hiperparâmetros encontrados;
# - Comparação entre modelos iniciais e modelos regularizados;
# - Criação de novas features temporais:
#     - `hora_sin / hora_cos`;
#     - `mes_sin / mes_cos`;
#     - `dia_semana_sin / dia_semana_cos`;
#     - `PM2.5_diff_1h`;
#     - `PM2.5_diff_3h`;
#     - `PM2.5_diff_6h`;
#     - `PM2.5_diff_24h`;
# - Treinamento de XGBoost inicial com as novas features temporais;
# - Treinamento de XGBoost regularizado com as novas features temporais;
# - Comparação final entre:
#     - `Modelos iniciais`;
#     - `Modelos regularizados`;
#     - `Modelos iniciais com features temporais`;
#     - `Modelos regularizados com features temporais`.
#
#
# ## Observação
#
# Nesta etapa, o foco foi comparar diferentes versões do `XGBoost` para previsão de `MP2.5` 24 horas à frente. A regularização reduziu sinais de overfitting nas learning curves, mas não trouxe ganho consistente no conjunto de teste. As novas features temporais também não apresentaram melhora expressiva e consistente nas métricas finais.
#
# De forma geral, os modelos apresentaram desempenhos próximos entre as três estratégias de pré-processamento. A seleção final deve considerar principalmente o desempenho em validação, a estabilidade entre validação e teste e a simplicidade da configuração.
#
# A base utilizada corresponde ao período histórico de ***2013 a 2019*** e mantém as seguintes features meteorológicas:
#
# - `temperature_2m`
# - `relative_humidity_2m`
# - `precipitation`
# - `wind_speed_10m`
#
# A ideia é comparar esta abordagem com o pré-processamento anterior do grupo, avaliando posteriormente qual estratégia gera melhor desempenho nos modelos.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from xgboost import XGBRegressor
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve, TimeSeriesSplit, GridSearchCV

# %%
# Importando as bases de dados 2013-2019
# Estrategia 1 sem imterpolação temporal / sazonal
df_estrategia01 = pd.read_csv("../data/processed_data/xgb_estrategia01_2013_2019_target_24h.csv")
df_estrategia01.head()
# Out:
#                         time  MP2.5  temperature_2m  relative_humidity_2m  \
# 0  2013-05-12 01:00:00+00:00   41.0          15.951             99.363174
# 1  2013-05-12 02:00:00+00:00   55.0          15.601             99.680275
# 2  2013-05-12 03:00:00+00:00   52.0          15.351             99.360230
# 3  2013-05-12 04:00:00+00:00   39.0          15.101             99.358990
# 4  2013-05-12 05:00:00+00:00   22.0          14.751             99.357250
#
#    precipitation  wind_speed_10m  target_24h  mes  hora  dia_semana  \
# 0            0.0        6.193674        62.0    5     1           6
# 1            0.0        6.915374        68.0    5     2           6
# 2            0.0        6.439876        70.0    5     3           6
# 3            0.0        6.725354        66.0    5     4           6
# 4            0.0        5.447788        80.0    5     5           6
#
#    PM2.5_lag_1h  PM2.5_lag_3h  PM2.5_lag_6h  PM2.5_lag_12h  PM2.5_lag_24h  \
# ...

# %%
# Estrategia 2 com imterpolação tempora em gaps menores 
df_estrategia02 = pd.read_csv("../data/processed_data/xgb_estrategia02_2013_2019_target_24h.csv")
df_estrategia02.head()
# Out:
#                         time  MP2.5  temperature_2m  relative_humidity_2m  \
# 0  2013-05-10 03:00:00+00:00   32.0       11.601000             99.670166
# 1  2013-05-10 04:00:00+00:00   23.0       11.401000             99.669660
# 2  2013-05-10 05:00:00+00:00   18.0       11.201000             99.339226
# 3  2013-05-10 06:00:00+00:00   20.0       10.801001             99.337160
# 4  2013-05-10 07:00:00+00:00   32.0       10.701000             98.348854
#
#    precipitation  wind_speed_10m  target_24h  mes  hora  dia_semana  \
# 0            0.0        3.893995        44.0    5     3           4
# 1            0.0        3.054701        25.0    5     4           4
# 2            0.0        4.582052        18.0    5     5           4
# 3            0.0        5.091168        15.0    5     6           4
# 4            0.0        5.091168        19.0    5     7           4
#
#    PM2.5_lag_1h  PM2.5_lag_3h  PM2.5_lag_6h  PM2.5_lag_12h  PM2.5_lag_24h  \
# ...

# %%
# Estrategia 3 com imputação sazonal em gaps menores e imterpolação temporal em gaps menores
df_estrategia03 = pd.read_csv("../data/processed_data/xgb_estrategia03_2013_2019_target_24h.csv")
df_estrategia03.head()
# Out:
#                         time  MP2.5  temperature_2m  relative_humidity_2m  \
# 0  2013-05-10 03:00:00+00:00   32.0       11.601000             99.670166
# 1  2013-05-10 04:00:00+00:00   23.0       11.401000             99.669660
# 2  2013-05-10 05:00:00+00:00   18.0       11.201000             99.339226
# 3  2013-05-10 06:00:00+00:00   20.0       10.801001             99.337160
# 4  2013-05-10 07:00:00+00:00   32.0       10.701000             98.348854
#
#    precipitation  wind_speed_10m  mes  hora  dia_semana  MP2.5_imputado_media  \
# 0            0.0        3.893995    5     3           4                     0
# 1            0.0        3.054701    5     4           4                     0
# 2            0.0        4.582052    5     5           4                     0
# 3            0.0        5.091168    5     6           4                     0
# 4            0.0        5.091168    5     7           4                     0
#
# ...

# %% [markdown]
# ### fazer split temporal

# %%
df_estrategia01 = df_estrategia01.drop(columns='MP2.5')
df_estrategia01.head()
# Out:
#                         time  temperature_2m  relative_humidity_2m  \
# 0  2013-05-12 01:00:00+00:00          15.951             99.363174
# 1  2013-05-12 02:00:00+00:00          15.601             99.680275
# 2  2013-05-12 03:00:00+00:00          15.351             99.360230
# 3  2013-05-12 04:00:00+00:00          15.101             99.358990
# 4  2013-05-12 05:00:00+00:00          14.751             99.357250
#
#    precipitation  wind_speed_10m  target_24h  mes  hora  dia_semana  \
# 0            0.0        6.193674        62.0    5     1           6
# 1            0.0        6.915374        68.0    5     2           6
# 2            0.0        6.439876        70.0    5     3           6
# 3            0.0        6.725354        66.0    5     4           6
# 4            0.0        5.447788        80.0    5     5           6
#
#    PM2.5_lag_1h  PM2.5_lag_3h  PM2.5_lag_6h  PM2.5_lag_12h  PM2.5_lag_24h  \
# 0          36.0          29.0          32.0           26.0            7.0
# ...

# %%
df_estrategia02 = df_estrategia02.drop(columns='MP2.5')
df_estrategia02.head()
# Out:
#                         time  temperature_2m  relative_humidity_2m  \
# 0  2013-05-10 03:00:00+00:00       11.601000             99.670166
# 1  2013-05-10 04:00:00+00:00       11.401000             99.669660
# 2  2013-05-10 05:00:00+00:00       11.201000             99.339226
# 3  2013-05-10 06:00:00+00:00       10.801001             99.337160
# 4  2013-05-10 07:00:00+00:00       10.701000             98.348854
#
#    precipitation  wind_speed_10m  target_24h  mes  hora  dia_semana  \
# 0            0.0        3.893995        44.0    5     3           4
# 1            0.0        3.054701        25.0    5     4           4
# 2            0.0        4.582052        18.0    5     5           4
# 3            0.0        5.091168        15.0    5     6           4
# 4            0.0        5.091168        19.0    5     7           4
#
#    PM2.5_lag_1h  PM2.5_lag_3h  PM2.5_lag_6h  PM2.5_lag_12h  PM2.5_lag_24h  \
# 0          39.0          12.0          32.0           27.0           26.0
# ...

# %%
df_estrategia03 = df_estrategia03.drop(columns='MP2.5')
df_estrategia03.head()
# Out:
#                         time  temperature_2m  relative_humidity_2m  \
# 0  2013-05-10 03:00:00+00:00       11.601000             99.670166
# 1  2013-05-10 04:00:00+00:00       11.401000             99.669660
# 2  2013-05-10 05:00:00+00:00       11.201000             99.339226
# 3  2013-05-10 06:00:00+00:00       10.801001             99.337160
# 4  2013-05-10 07:00:00+00:00       10.701000             98.348854
#
#    precipitation  wind_speed_10m  mes  hora  dia_semana  MP2.5_imputado_media  \
# 0            0.0        3.893995    5     3           4                     0
# 1            0.0        3.054701    5     4           4                     0
# 2            0.0        4.582052    5     5           4                     0
# 3            0.0        5.091168    5     6           4                     0
# 4            0.0        5.091168    5     7           4                     0
#
#    target_24h  PM2.5_lag_1h  PM2.5_lag_3h  PM2.5_lag_6h  PM2.5_lag_12h  \
# ...

# %%
#Selecionando as features para o modelo
features = [
    "temperature_2m",
    "relative_humidity_2m",
    "precipitation",
    "wind_speed_10m",
    "mes",
    "hora",
    "dia_semana",
    "PM2.5_lag_1h",
    "PM2.5_lag_3h",
    "PM2.5_lag_6h",
    "PM2.5_lag_12h",
    "PM2.5_lag_24h",
    "PM2.5_rolling_mean_3h",
    "PM2.5_rolling_mean_6h",
    "PM2.5_rolling_mean_12h",
    "PM2.5_rolling_mean_24h",
    "PM2.5_rolling_std_24h"
]

target = "target_24h"

# %%
df_estrategia01["time"] = pd.to_datetime(df_estrategia01["time"])
df_estrategia02["time"] = pd.to_datetime(df_estrategia02["time"])
df_estrategia03["time"] = pd.to_datetime(df_estrategia03["time"])

# %%
#função para split temporal
def split_temporal(df, features, target):
    df = df.sort_values("time").copy()

    train = df[df["time"] < "2018-01-01"].copy()
    val = df[(df["time"] >= "2018-01-01") & (df["time"] < "2019-01-01")].copy()
    test = df[df["time"] >= "2019-01-01"].copy()

    X_train = train[features]
    y_train = train[target]

    X_val = val[features]
    y_val = val[target]

    X_test = test[features]
    y_test = test[target]

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
#split na 1 estrategia
X_train_01, X_val_01, X_test_01, y_train_01, y_val_01, y_test_01 = split_temporal(
    df_estrategia01, features, target
)

# %%
#split na 2 estrategia
X_train_02, X_val_02, X_test_02, y_train_02, y_val_02, y_test_02 = split_temporal(
    df_estrategia02, features, target
)

# %%
#split na 3 estrategia
X_train_03, X_val_03, X_test_03, y_train_03, y_val_03, y_test_03 = split_temporal(
    df_estrategia03, features, target
)

# %%
print(X_train_01.shape, X_val_01.shape, X_test_01.shape)
print(X_train_02.shape, X_val_02.shape, X_test_02.shape)
print(X_train_03.shape, X_val_03.shape, X_test_03.shape)
# Out:
# (34790, 17) (7475, 17) (5010, 17)
# (37817, 17) (7604, 17) (5221, 17)
# (40725, 17) (8760, 17) (5475, 17)

# %%
#vendo se ainda reside nan nos X
print(X_train_01.isna().sum().sum(), X_val_01.isna().sum().sum(), X_test_01.isna().sum().sum())
print(X_train_02.isna().sum().sum(), X_val_02.isna().sum().sum(), X_test_02.isna().sum().sum())
print(X_train_03.isna().sum().sum(), X_val_03.isna().sum().sum(), X_test_03.isna().sum().sum())
# Out:
# 0 0 0
# 0 0 0
# 0 0 0

# %%
#vendo se ainda reside nan nos Y
print(y_train_01.isna().sum(), y_val_01.isna().sum(), y_test_01.isna().sum())
print(y_train_02.isna().sum(), y_val_02.isna().sum(), y_test_02.isna().sum())
print(y_train_03.isna().sum(), y_val_03.isna().sum(), y_test_03.isna().sum())
# Out:
# 0 0 0
# 0 0 0
# 0 0 0

# %% [markdown]
# ### Avaliação Baseline

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
def avaliar_modelo(y_true, y_pred):
    return {
        "MAE": mean_absolute_error(y_true, y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_true, y_pred)),
        "R2": r2_score(y_true, y_pred)
    }

# %%
y_pred_baseline_01 = X_val_01["PM2.5_lag_24h"]
y_pred_baseline_02 = X_val_02["PM2.5_lag_24h"]
y_pred_baseline_03 = X_val_03["PM2.5_lag_24h"]

baseline_01 = avaliar_modelo(y_val_01, y_pred_baseline_01)
baseline_02 = avaliar_modelo(y_val_02, y_pred_baseline_02)
baseline_03 = avaliar_modelo(y_val_03, y_pred_baseline_03)

baseline_01, baseline_02, baseline_03
# Out:
# ({'MAE': 11.016989966555183,
#   'RMSE': 15.610750090711491,
#   'R2': -0.39173078414061124},
#  {'MAE': 11.028581448360514,
#   'RMSE': 15.646441218400593,
#   'R2': -0.411274593292444},
#  {'MAE': 10.51950426132376,
#   'RMSE': 15.012342447173122,
#   'R2': -0.4051236520504613})

# %% [markdown]
# ### Pipeline do Modelo XGBoost - Utilizando Simple Imputer

# %%
def train(X_train, y_train, X_val, y_val):
    pipeline = make_pipeline(
        SimpleImputer(strategy="median"),
        XGBRegressor(
            objective="reg:squarederror",
            n_estimators=500,
            learning_rate=0.05,
            max_depth=5,
            subsample=0.8,
            colsample_bytree=0.8,
            random_state=42
        )
    )

    pipeline.fit(X_train, y_train)

    y_pred = pipeline.predict(X_val)

    resultados = {
        "MAE": mean_absolute_error(y_val, y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_val, y_pred)),
        "R2": r2_score(y_val, y_pred)
    }

    return pipeline, y_pred, resultados

# %%
modelo_01, y_pred_val_01, resultados_xgb_01 = train(
    X_train_01, y_train_01, X_val_01, y_val_01
)

# %%
modelo_02, y_pred_val_02, resultados_xgb_02 = train(
    X_train_02, y_train_02, X_val_02, y_val_02
)

# %%
modelo_03, y_pred_val_03, resultados_xgb_03 = train(
    X_train_03, y_train_03, X_val_03, y_val_03
)

# %%
resultados_comparacao = pd.DataFrame([
    {"estrategia": "Estratégia 1", "modelo": "Baseline lag_24h", **baseline_01},
    {"estrategia": "Estratégia 1", "modelo": "XGBoost", **resultados_xgb_01},

    {"estrategia": "Estratégia 2", "modelo": "Baseline lag_24h", **baseline_02},
    {"estrategia": "Estratégia 2", "modelo": "XGBoost", **resultados_xgb_02},

    {"estrategia": "Estratégia 3", "modelo": "Baseline lag_24h", **baseline_03},
    {"estrategia": "Estratégia 3", "modelo": "XGBoost", **resultados_xgb_03},
])

resultados_comparacao
# Out:
#      estrategia            modelo        MAE       RMSE        R2
# 0  Estratégia 1  Baseline lag_24h  11.016990  15.610750 -0.391731
# 1  Estratégia 1           XGBoost   8.162475  11.284596  0.272757
# 2  Estratégia 2  Baseline lag_24h  11.028581  15.646441 -0.411275
# 3  Estratégia 2           XGBoost   8.188678  11.361140  0.255912
# 4  Estratégia 3  Baseline lag_24h  10.519504  15.012342 -0.405124
# 5  Estratégia 3           XGBoost   7.798056  10.957379  0.251432

# %%
y_pred_test_03 = modelo_03.predict(X_test_03)

resultados_test_03 = avaliar_modelo(y_test_03, y_pred_test_03)

resultados_test_03
# Out:
# {'MAE': 7.888167358487483,
#  'RMSE': 10.881100969105814,
#  'R2': 0.28562611536536064}

# %%
y_pred_test_01 = modelo_01.predict(X_test_01)
y_pred_test_02 = modelo_02.predict(X_test_02)
y_pred_test_03 = modelo_03.predict(X_test_03)

resultados_test_01 = avaliar_modelo(y_test_01, y_pred_test_01)
resultados_test_02 = avaliar_modelo(y_test_02, y_pred_test_02)
resultados_test_03 = avaliar_modelo(y_test_03, y_pred_test_03)

pd.DataFrame([
    {"estrategia": "Estratégia 1", "modelo": "XGBoost", "split": "Teste", **resultados_test_01},
    {"estrategia": "Estratégia 2", "modelo": "XGBoost", "split": "Teste", **resultados_test_02},
    {"estrategia": "Estratégia 3", "modelo": "XGBoost", "split": "Teste", **resultados_test_03},
])
# Out:
#      estrategia   modelo  split       MAE       RMSE        R2
# 0  Estratégia 1  XGBoost  Teste  7.843688  10.826835  0.278049
# 1  Estratégia 2  XGBoost  Teste  7.924267  10.965247  0.278327
# 2  Estratégia 3  XGBoost  Teste  7.888167  10.881101  0.285626

# %% [markdown]
# ### No conjunto de teste, o XGBoost apresentou desempenho superior ao baseline, mantendo R² positivo nas três estratégias. A Estratégia 3 obteve o maior R² e desempenho competitivo em MAE e RMSE, indicando que a imputação sazonal pode ter contribuído para maior aproveitamento da série temporal. No entanto, as diferenças entre as estratégias foram pequenas, sugerindo que todas apresentam desempenho semelhante para a previsão de PM2.5 24 horas à frente.

# %%
modelo_xgb_03 = modelo_03.named_steps["xgbregressor"]
modelo_xgb_03.get_params()
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': 0.8,
#  'device': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': 0.05,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': 5,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'multi_strategy': None,
#  'n_estimators': 500,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'random_state': 42,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': 0.8,
#  'tree_method': None,
#  'validate_parameters': None,
# ...

# %%
feature_importance_03 = pd.DataFrame({
    "feature": X_train_03.columns,
    "importance": modelo_xgb_03.feature_importances_
}).sort_values("importance", ascending=False)

feature_importance_03
# Out:
#                    feature  importance
# 7             PM2.5_lag_1h    0.175654
# 12   PM2.5_rolling_mean_3h    0.112533
# 5                     hora    0.079221
# 13   PM2.5_rolling_mean_6h    0.073207
# 2            precipitation    0.071195
# 0           temperature_2m    0.064289
# 4                      mes    0.046111
# 6               dia_semana    0.045195
# 3           wind_speed_10m    0.044014
# 15  PM2.5_rolling_mean_24h    0.042194
# 11           PM2.5_lag_24h    0.041949
# 14  PM2.5_rolling_mean_12h    0.041691
# 16   PM2.5_rolling_std_24h    0.036771
# 1     relative_humidity_2m    0.034067
# 9             PM2.5_lag_6h    0.033599
# 10           PM2.5_lag_12h    0.030828
# 8             PM2.5_lag_3h    0.027483

# %%
feature_importance_03.head(15).plot(
    x="feature",
    y="importance",
    kind="barh",
    figsize=(8, 6),
    legend=False
)

plt.gca().invert_yaxis()
plt.title("Feature Importance - XGBoost Estratégia 3")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### o modelo está usando histórico recente, padrão horário e meteorologia como bengala para as previsões

# %%
def avaliar_splits_modelo(modelo, X_train, y_train, X_val, y_val, X_test, y_test):
    y_pred_train = modelo.predict(X_train)
    y_pred_val = modelo.predict(X_val)
    y_pred_test = modelo.predict(X_test)

    resultados = pd.DataFrame([
        {"split": "Train", **avaliar_modelo(y_train, y_pred_train)},
        {"split": "Validation", **avaliar_modelo(y_val, y_pred_val)},
        {"split": "Test", **avaliar_modelo(y_test, y_pred_test)},
    ])

    return resultados

# %% [markdown]
# ### Vendo as diferenças das métricas entre treino-validação e teste

# %%
resultados_splits_03 = avaliar_splits_modelo(
    modelo_03,
    X_train_03, y_train_03,
    X_val_03, y_val_03,
    X_test_03, y_test_03
)

resultados_splits_03
# Out:
#         split       MAE       RMSE        R2
# 0       Train  6.891693   9.410215  0.520867
# 1  Validation  7.798056  10.957379  0.251432
# 2        Test  7.888167  10.881101  0.285626

# %%
resultados_splits_03.plot(
    x="split",
    y=["MAE", "RMSE"],
    kind="bar",
    figsize=(8, 5)
)

plt.title("Desempenho por Split - XGBoost Estratégia 3")
plt.ylabel("Erro")
plt.xlabel("Split")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### O modelo parace treinar melhor no passado e generaliza de forma razoável. suspeita um pouco de overfitting

# %% [markdown]
# ### Retreinar o modelo para ver o learning curve

# %%
pipeline_xgb = make_pipeline(
    SimpleImputer(strategy="median"),
    XGBRegressor(
        objective="reg:squarederror",
        n_estimators=500,
        learning_rate=0.05,
        max_depth=5,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42,
        n_jobs=-1
    )
)

# %%
tscv = TimeSeriesSplit(n_splits=5)

train_sizes, train_scores, val_scores = learning_curve(
    estimator=pipeline_xgb,
    X=X_train_03,
    y=y_train_03,
    train_sizes=np.linspace(0.1, 1.0, 5),
    cv=tscv,
    scoring="neg_root_mean_squared_error",
    n_jobs=-1
)

# %%
train_rmse = -train_scores
val_rmse = -val_scores

train_rmse_mean = train_rmse.mean(axis=1)
train_rmse_std = train_rmse.std(axis=1)

val_rmse_mean = val_rmse.mean(axis=1)
val_rmse_std = val_rmse.std(axis=1)

# %%
plt.figure(figsize=(10, 5))

plt.plot(train_sizes, train_rmse_mean, marker="o", label="Train RMSE")
plt.plot(train_sizes, val_rmse_mean, marker="o", label="Validation RMSE")

plt.fill_between(
    train_sizes,
    train_rmse_mean - train_rmse_std,
    train_rmse_mean + train_rmse_std,
    alpha=0.2
)

plt.fill_between(
    train_sizes,
    val_rmse_mean - val_rmse_std,
    val_rmse_mean + val_rmse_std,
    alpha=0.2
)

plt.title("Learning Curve - XGBoost Estratégia 3")
plt.xlabel("Tamanho do treino")
plt.ylabel("RMSE")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Isso sugere tendência de overfitting - alta variância. O modelo consegue se ajustar bem ao treino, mas não reduz tanto o erro de validação.
#
# ### Também dá para ver que a validação melhora no começo, mas depois estabiliza perto de RMSE 12–13. Isso indica que só aumentar os dados de treino, do jeito que está, não está melhorando muito.

# %%
train_sizes, train_scores, val_scores = learning_curve(
    estimator=pipeline_xgb,
    X=X_train_02,
    y=y_train_02,
    train_sizes=np.linspace(0.1, 1.0, 5),
    cv=tscv,
    scoring="neg_root_mean_squared_error",
    n_jobs=-1
)

# %%
train_rmse = -train_scores
val_rmse = -val_scores

train_rmse_mean = train_rmse.mean(axis=1)
train_rmse_std = train_rmse.std(axis=1)

val_rmse_mean = val_rmse.mean(axis=1)
val_rmse_std = val_rmse.std(axis=1)

# %%
plt.figure(figsize=(10, 5))

plt.plot(train_sizes, train_rmse_mean, marker="o", label="Train RMSE")
plt.plot(train_sizes, val_rmse_mean, marker="o", label="Validation RMSE")

plt.fill_between(
    train_sizes,
    train_rmse_mean - train_rmse_std,
    train_rmse_mean + train_rmse_std,
    alpha=0.2
)

plt.fill_between(
    train_sizes,
    val_rmse_mean - val_rmse_std,
    val_rmse_mean + val_rmse_std,
    alpha=0.2
)

plt.title("Learning Curve - XGBoost Estratégia 2")
plt.xlabel("Tamanho do treino")
plt.ylabel("RMSE")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
train_sizes, train_scores, val_scores = learning_curve(
    estimator=pipeline_xgb,
    X=X_train_01,
    y=y_train_01,
    train_sizes=np.linspace(0.1, 1.0, 5),
    cv=tscv,
    scoring="neg_root_mean_squared_error",
    n_jobs=-1
)

# %%
train_rmse = -train_scores
val_rmse = -val_scores

train_rmse_mean = train_rmse.mean(axis=1)
train_rmse_std = train_rmse.std(axis=1)

val_rmse_mean = val_rmse.mean(axis=1)
val_rmse_std = val_rmse.std(axis=1)

# %%
plt.figure(figsize=(10, 5))

plt.plot(train_sizes, train_rmse_mean, marker="o", label="Train RMSE")
plt.plot(train_sizes, val_rmse_mean, marker="o", label="Validation RMSE")

plt.fill_between(
    train_sizes,
    train_rmse_mean - train_rmse_std,
    train_rmse_mean + train_rmse_std,
    alpha=0.2
)

plt.fill_between(
    train_sizes,
    val_rmse_mean - val_rmse_std,
    val_rmse_mean + val_rmse_std,
    alpha=0.2
)

plt.title("Learning Curve - XGBoost Estratégia 1")
plt.xlabel("Tamanho do treino")
plt.ylabel("RMSE")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### As learning curves das três estratégias indicam uma diferença relevante entre o erro de treino e o erro de validação, sugerindo tendência de overfitting. A validação estabiliza após determinado volume de dados, indicando que apenas aumentar a quantidade de treino não reduz  o erro. Não há evidência clara de data leakage, pois o erro de validação permanece consideravelmente acima do erro de treino.

# %% [markdown]
# ## Vou testar o modelo com hiperparâmetros diferentes

# %%
xgb_base = XGBRegressor(
    objective="reg:squarederror",
    eval_metric="rmse",
    random_state=42,
    n_jobs=-1
)

# %%
param_grid = {
    "n_estimators": [300, 500, 800],
    "learning_rate": [0.01, 0.03, 0.05],
    "max_depth": [2, 3, 4],
    "min_child_weight": [3, 5, 7],
    "subsample": [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0],
    "reg_lambda": [1, 5, 10],
    "reg_alpha": [0, 0.1, 0.5]
}

# %%
tscv = TimeSeriesSplit(n_splits=5)

grid_xgb_03 = GridSearchCV(
    estimator=xgb_base,
    param_grid=param_grid,
    scoring="neg_root_mean_squared_error",
    cv=tscv,
    n_jobs=-1,
    verbose=
)

grid_xgb_03.fit(X_train_03, y_train_03)
# Out:
# Fitting 5 folds for each of 2916 candidates, totalling 14580 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=2, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=2, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=2, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=5, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=2, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=2, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=10, subsample=1.0; total time=   0.2s
# ...

# %%
grid_xgb_03.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'learning_rate': 0.01,
#  'max_depth': 4,
#  'min_child_weight': 7,
#  'n_estimators': 500,
#  'reg_alpha': 0.5,
#  'reg_lambda': 10,
#  'subsample': 0.8}

# %%
-grid_xgb_03.best_score_
# Out:
# 11.735765499395592

# %%
best_params_03 = grid_xgb_03.best_params_

xgb_reg_03 = XGBRegressor(
    objective="reg:squarederror",
    eval_metric="rmse",
    random_state=42,
    n_jobs=-1,
    early_stopping_rounds=50,
    **best_params_03
)

xgb_reg_03.fit(
    X_train_03,
    y_train_03,
    eval_set=[(X_val_03, y_val_03)],
    verbose=0
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=7, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=-1,
#              num_parallel_tree=None, random_state=42, ...)

# %%
y_pred_val_reg_03 = xgb_reg_03.predict(X_val_03)

resultados_reg_03 = avaliar_modelo(y_val_03, y_pred_val_reg_03)

resultados_reg_03
# Out:
# {'MAE': 7.702338780022624,
#  'RMSE': 10.678634944805037,
#  'R2': 0.28903356272235214}

# %%
comparacao_val_03 = pd.DataFrame([
    {"modelo": "XGBoost inicial - Estratégia 3", **resultados_xgb_03},
    {"modelo": "XGBoost regularizado - Estratégia 3", **resultados_reg_03}
])

comparacao_val_03
# Out:
#                                 modelo       MAE       RMSE        R2
# 0       XGBoost inicial - Estratégia 3  7.798056  10.957379  0.251432
# 1  XGBoost regularizado - Estratégia 3  7.702339  10.678635  0.289034

# %%
y_pred_train_reg_03 = xgb_reg_03.predict(X_train_03)
y_pred_val_reg_03 = xgb_reg_03.predict(X_val_03)

overfit_reg_03 = pd.DataFrame([
    {"split": "Train", **avaliar_modelo(y_train_03, y_pred_train_reg_03)},
    {"split": "Validation", **avaliar_modelo(y_val_03, y_pred_val_reg_03)}
])

overfit_reg_03
# Out:
#         split       MAE       RMSE        R2
# 0       Train  8.067819  11.336403  0.304643
# 1  Validation  7.702339  10.678635  0.289034

# %%
print("Melhor iteração:", xgb_reg_03.best_iteration)
print("Melhor score:", xgb_reg_03.best_score)
# Out:
# Melhor iteração: 499
# Melhor score: 10.678634943224537

# %%
def grid_regularizar_xgb(X_train, y_train, X_val, y_val, nome_estrategia):
    xgb_base = XGBRegressor(
        objective="reg:squarederror",
        eval_metric="rmse",
        random_state=42,
        n_jobs=-1
    )

    param_grid = {
        "n_estimators": [300, 500, 800],
        "learning_rate": [0.01, 0.03, 0.05],
        "max_depth": [2, 3, 4],
        "min_child_weight": [3, 5, 7],
        "subsample": [0.8, 1.0],
        "colsample_bytree": [0.8, 1.0],
        "reg_lambda": [1, 5, 10],
        "reg_alpha": [0, 0.1, 0.5]
    }

    tscv = TimeSeriesSplit(n_splits=5)

    grid = GridSearchCV(
        estimator=xgb_base,
        param_grid=param_grid,
        scoring="neg_root_mean_squared_error",
        cv=tscv,
        n_jobs=-1,
        verbose=0
    )

    grid.fit(X_train, y_train)

    best_params = grid.best_params_

    modelo_final = XGBRegressor(
        objective="reg:squarederror",
        eval_metric="rmse",
        random_state=42,
        n_jobs=-1,
        early_stopping_rounds=50,
        **best_params
    )

    modelo_final.fit(
        X_train,
        y_train,
        eval_set=[(X_val, y_val)],
        verbose=0
    )

    y_pred_val = modelo_final.predict(X_val)

    resultados = avaliar_modelo(y_val, y_pred_val)

    print(nome_estrategia)
    print("Melhores parâmetros:", best_params)
    print("Melhor RMSE CV:", -grid.best_score_)
    print("Melhor iteração:", modelo_final.best_iteration)
    print("Resultados validação:", resultados)

    return grid, modelo_final, y_pred_val, resultados

# %%
grid_01, xgb_reg_01, y_pred_val_reg_01, resultados_reg_01 = grid_regularizar_xgb(
    X_train_01, y_train_01,
    X_val_01, y_val_01,
    "Estratégia 1"
)
# Out:
# Estratégia 1
# Melhores parâmetros: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 0.8}
# Melhor RMSE CV: 12.079922482479256
# Melhor iteração: 494
# Resultados validação: {'MAE': 8.131163488279617, 'RMSE': 11.130490049208067, 'R2': 0.2924840049059635}

# %%
grid_02, xgb_reg_02, y_pred_val_reg_02, resultados_reg_02 = grid_regularizar_xgb(
    X_train_02, y_train_02,
    X_val_02, y_val_02,
    "Estratégia 2"
)
# Out:
# Estratégia 2
# Melhores parâmetros: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 7, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 0.8}
# Melhor RMSE CV: 12.108568318087162
# Melhor iteração: 497
# Resultados validação: {'MAE': 8.09546777413181, 'RMSE': 11.089522917722455, 'R2': 0.2910655141816223}

# %%
comparacao_reg = pd.DataFrame([
    {"estrategia": "Estratégia 1", "modelo": "Inicial", **resultados_xgb_01},
    {"estrategia": "Estratégia 1", "modelo": "Regularizado", **resultados_reg_01},

    {"estrategia": "Estratégia 2", "modelo": "Inicial", **resultados_xgb_02},
    {"estrategia": "Estratégia 2", "modelo": "Regularizado", **resultados_reg_02},

    {"estrategia": "Estratégia 3", "modelo": "Inicial", **resultados_xgb_03},
    {"estrategia": "Estratégia 3", "modelo": "Regularizado", **resultados_reg_03},
])

comparacao_regularizacao
# Out:
#      estrategia        modelo       MAE       RMSE        R2
# 0  Estratégia 1       Inicial  8.162475  11.284596  0.272757
# 1  Estratégia 1  Regularizado  8.131163  11.130490  0.292484
# 2  Estratégia 2       Inicial  8.188678  11.361140  0.255912
# 3  Estratégia 2  Regularizado  8.095468  11.089523  0.291066
# 4  Estratégia 3       Inicial  7.798056  10.957379  0.251432
# 5  Estratégia 3  Regularizado  7.702339  10.678635  0.289034

# %%
def plot_learning_curve_reg(X_train, y_train, best_params, titulo):
    modelo = XGBRegressor(
        objective="reg:squarederror",
        eval_metric="rmse",
        random_state=42,
        n_jobs=-1,
        **best_params
    )

    tscv = TimeSeriesSplit(n_splits=5)

    train_sizes, train_scores, val_scores = learning_curve(
        estimator=modelo,
        X=X_train,
        y=y_train,
        train_sizes=np.linspace(0.1, 1.0, 5),
        cv=tscv,
        scoring="neg_root_mean_squared_error",
        n_jobs=-1
    )

    train_rmse = -train_scores
    val_rmse = -val_scores

    train_rmse_mean = train_rmse.mean(axis=1)
    train_rmse_std = train_rmse.std(axis=1)

    val_rmse_mean = val_rmse.mean(axis=1)
    val_rmse_std = val_rmse.std(axis=1)

    plt.figure(figsize=(10, 5))

    plt.plot(train_sizes, train_rmse_mean, marker="o", label="Train RMSE")
    plt.plot(train_sizes, val_rmse_mean, marker="o", label="Validation RMSE")

    plt.fill_between(
        train_sizes,
        train_rmse_mean - train_rmse_std,
        train_rmse_mean + train_rmse_std,
        alpha=0.2
    )

    plt.fill_between(
        train_sizes,
        val_rmse_mean - val_rmse_std,
        val_rmse_mean + val_rmse_std,
        alpha=0.2
    )

    plt.title(titulo)
    plt.xlabel("Tamanho do treino")
    plt.ylabel("RMSE")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
plot_learning_curve_reg(
    X_train_01,
    y_train_01,
    grid_01.best_params_,
    "Learning Curve - XGBoost Regularizado Estratégia 1"
)

plot_learning_curve_reg(
    X_train_02,
    y_train_02,
    grid_02.best_params_,
    "Learning Curve - XGBoost Regularizado Estratégia 2"
)

plot_learning_curve_reg(
    X_train_03,
    y_train_03,
    grid_xgb_03.best_params_,
    "Learning Curve - XGBoost Regularizado Estratégia 3"
)

# %%
y_pred_test_reg_03 = xgb_reg_03.predict(X_test_03)

resultados_test_reg_03 = avaliar_modelo(y_test_03, y_pred_test_reg_03)

resultados_test_reg_03
# Out:
# {'MAE': 7.949236302801661,
#  'RMSE': 10.892695972090667,
#  'R2': 0.28410281718837194}

# %%
y_pred_test_reg_02 = xgb_reg_02.predict(X_test_02)

resultados_test_reg_02 = avaliar_modelo(y_test_02, y_pred_test_reg_02)

resultados_test_reg_02
# Out:
# {'MAE': 8.01380242700436, 'RMSE': 10.979199855535803, 'R2': 0.2764893318551266}

# %%
y_pred_test_reg_01 = xgb_reg_01.predict(X_test_01)

resultados_test_reg_01 = avaliar_modelo(y_test_01, y_pred_test_reg_01)

resultados_test_reg_01
# Out:
# {'MAE': 7.950550094193328,
#  'RMSE': 10.869112030675858,
#  'R2': 0.27240007771648256}

# %%
comparacao_test_reg = pd.DataFrame([
    {"estrategia": "Estratégia 1", "modelo": "XGBoost Regularizado", **resultados_test_reg_01},
    {"estrategia": "Estratégia 2", "modelo": "XGBoost Regularizado", **resultados_test_reg_02},
    {"estrategia": "Estratégia 3", "modelo": "XGBoost Regularizado", **resultados_test_reg_03},
])

comparacao_test_reg
# Out:
#      estrategia                modelo       MAE       RMSE        R2
# 0  Estratégia 1  XGBoost Regularizado  7.950550  10.869112  0.272400
# 1  Estratégia 2  XGBoost Regularizado  8.013802  10.979200  0.276489
# 2  Estratégia 3  XGBoost Regularizado  7.949236  10.892696  0.284103

# %% [markdown]
# ### Após a regularização, os modelos apresentaram melhora nas métricas de validação, especialmente na Estratégia 3. No conjunto de teste, entretanto, os resultados permaneceram muito próximos aos modelos iniciais, indicando que a regularização reduziu sinais de overfitting, mas não trouxe ganho expressivo de generalização no horizonte de 24h. As três estratégias apresentaram desempenho semelhante, com pequena vantagem da Estratégia 3 em R² e da Estratégia 1 em RMSE.¶

# %%
comparacao_test_models= pd.DataFrame([
    {"estrategia": "Estratégia 1", "modelo": "XGBoost Sem Regularização", **resultados_test_01},
    {"estrategia": "Estratégia 1", "modelo": "XGBoost Regularizado", **resultados_test_reg_01},
    {"estrategia": "Estratégia 2", "modelo": "XGBoost Sem Regularização", **resultados_test_02},
    {"estrategia": "Estratégia 2", "modelo": "XGBoost Regularizado", **resultados_test_reg_02},
    {"estrategia": "Estratégia 3", "modelo": "XGBoost Sem Regularização", **resultados_test_03},
    {"estrategia": "Estratégia 3", "modelo": "XGBoost Regularizado", **resultados_test_reg_03},
])

comparacao_test_models
# Out:
#      estrategia                     modelo       MAE       RMSE        R2
# 0  Estratégia 1  XGBoost Sem Regularização  7.843688  10.826835  0.278049
# 1  Estratégia 1       XGBoost Regularizado  7.950550  10.869112  0.272400
# 2  Estratégia 2  XGBoost Sem Regularização  7.924267  10.965247  0.278327
# 3  Estratégia 2       XGBoost Regularizado  8.013802  10.979200  0.276489
# 4  Estratégia 3  XGBoost Sem Regularização  7.888167  10.881101  0.285626
# 5  Estratégia 3       XGBoost Regularizado  7.949236  10.892696  0.284103

# %% [markdown]
# ### A regularização melhorou os resultados na validação, mas não melhorou no conjunto de teste. No teste, os modelos sem regularização apresentaram desempenho ligeiramente melhor nas três estratégias.

# %% [markdown]
# ## Adicionar feature engineering temporal

# %%
def add_feat_temp(X):
    X = X.copy()

    # Features cíclicas
    X["hora_sin"] = np.sin(2 * np.pi * X["hora"] / 24)
    X["hora_cos"] = np.cos(2 * np.pi * X["hora"] / 24)

    X["mes_sin"] = np.sin(2 * np.pi * X["mes"] / 12)
    X["mes_cos"] = np.cos(2 * np.pi * X["mes"] / 12)

    X["dia_semana_sin"] = np.sin(2 * np.pi * X["dia_semana"] / 7)
    X["dia_semana_cos"] = np.cos(2 * np.pi * X["dia_semana"] / 7)

    # Features de tendência do PM2.5
    X["PM2.5_diff_1h"] = X["PM2.5_lag_1h"] - X["PM2.5_lag_3h"]
    X["PM2.5_diff_3h"] = X["PM2.5_lag_3h"] - X["PM2.5_lag_6h"]
    X["PM2.5_diff_6h"] = X["PM2.5_lag_6h"] - X["PM2.5_lag_12h"]
    X["PM2.5_diff_24h"] = X["PM2.5_lag_1h"] - X["PM2.5_lag_24h"]

    return X

# %%
#Adicionando as features
X_train_01_fe = add_feat_temp(X_train_01)
X_val_01_fe = add_feat_temp(X_val_01)
X_test_01_fe = add_feat_temp(X_test_01)

X_train_02_fe = add_feat_temp(X_train_02)
X_val_02_fe = add_feat_temp(X_val_02)
X_test_02_fe = add_feat_temp(X_test_02)

X_train_03_fe = add_feat_temp(X_train_03)
X_val_03_fe = add_feat_temp(X_val_03)
X_test_03_fe = add_feat_temp(X_test_03)

# %%
#Conferir se não gerou nan
print(X_train_01_fe.isna().sum().sum(), X_val_01_fe.isna().sum().sum(), X_test_01_fe.isna().sum().sum())
print(X_train_02_fe.isna().sum().sum(), X_val_02_fe.isna().sum().sum(), X_test_02_fe.isna().sum().sum())
print(X_train_03_fe.isna().sum().sum(), X_val_03_fe.isna().sum().sum(), X_test_03_fe.isna().sum().sum())
# Out:
# 0 0 0
# 0 0 0
# 0 0 0

# %%
def train_xgb_initial_fe(X_train, y_train, X_val, y_val):
    modelo = XGBRegressor(
        objective="reg:squarederror",
        n_estimators=500,
        learning_rate=0.05,
        max_depth=5,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42,
        n_jobs=-1,
        eval_metric="rmse"
    )

    modelo.fit(X_train, y_train)

    y_pred_val = modelo.predict(X_val)
    resultados = avaliar_modelo(y_val, y_pred_val)

    return modelo, y_pred_val, resultados

# %%
xgb_ini_fe_01, y_pred_val_ini_fe_01, resultados_ini_fe_01 = train_xgb_initial_fe(
    X_train_01_fe, y_train_01, X_val_01_fe, y_val_01
)

xgb_ini_fe_02, y_pred_val_ini_fe_02, resultados_ini_fe_02 = train_xgb_initial_fe(
    X_train_02_fe, y_train_02, X_val_02_fe, y_val_02
)

xgb_ini_fe_03, y_pred_val_ini_fe_03, resultados_ini_fe_03 = train_xgb_initial_fe(
    X_train_03_fe, y_train_03, X_val_03_fe, y_val_03
)

# %%
def train_xgb_reg_fe(X_train, y_train, X_val, y_val, best_params):
    modelo = XGBRegressor(
        objective="reg:squarederror",
        eval_metric="rmse",
        random_state=42,
        n_jobs=-1,
        early_stopping_rounds=50,
        **best_params
    )

    modelo.fit(
        X_train,
        y_train,
        eval_set=[(X_val, y_val)],
        verbose=0
    )

    y_pred_val = modelo.predict(X_val)
    resultados = avaliar_modelo(y_val, y_pred_val)

    return modelo, y_pred_val, resultados

# %%
xgb_reg_fe_01, y_pred_val_reg_fe_01, resultados_reg_fe_01 = train_xgb_reg_fe(
    X_train_01_fe, y_train_01,
    X_val_01_fe, y_val_01,
    grid_01.best_params_
)

xgb_reg_fe_02, y_pred_val_reg_fe_02, resultados_reg_fe_02 = train_xgb_reg_fe(
    X_train_02_fe, y_train_02,
    X_val_02_fe, y_val_02,
    grid_02.best_params_
)

xgb_reg_fe_03, y_pred_val_reg_fe_03, resultados_reg_fe_03 = train_xgb_reg_fe(
    X_train_03_fe, y_train_03,
    X_val_03_fe, y_val_03,
    grid_xgb_03.best_params_
)

# %%
# Comparar tudo na validação
comp_val_all = pd.DataFrame([
    {"estrategia": "Estratégia 1", "modelo": "Inicial", **resultados_xgb_01},
    {"estrategia": "Estratégia 1", "modelo": "Regularizado", **resultados_reg_01},
    {"estrategia": "Estratégia 1", "modelo": "Inicial + Features Temporais", **resultados_ini_fe_01},
    {"estrategia": "Estratégia 1", "modelo": "Regularizado + Features Temporais", **resultados_reg_fe_01},

    {"estrategia": "Estratégia 2", "modelo": "Inicial", **resultados_xgb_02},
    {"estrategia": "Estratégia 2", "modelo": "Regularizado", **resultados_reg_02},
    {"estrategia": "Estratégia 2", "modelo": "Inicial + Features Temporais", **resultados_ini_fe_02},
    {"estrategia": "Estratégia 2", "modelo": "Regularizado + Features Temporais", **resultados_reg_fe_02},

    {"estrategia": "Estratégia 3", "modelo": "Inicial", **resultados_xgb_03},
    {"estrategia": "Estratégia 3", "modelo": "Regularizado", **resultados_reg_03},
    {"estrategia": "Estratégia 3", "modelo": "Inicial + Features Temporais", **resultados_ini_fe_03},
    {"estrategia": "Estratégia 3", "modelo": "Regularizado + Features Temporais", **resultados_reg_fe_03},
])

comp_val_all.sort_values("RMSE")
# Out:
#       estrategia                             modelo       MAE       RMSE  \
# 9   Estratégia 3                       Regularizado  7.702339  10.678635
# 11  Estratégia 3  Regularizado + Features Temporais  7.704222  10.704409
# 10  Estratégia 3       Inicial + Features Temporais  7.765421  10.923552
# 8   Estratégia 3                            Inicial  7.798056  10.957379
# 5   Estratégia 2                       Regularizado  8.095468  11.089523
# 7   Estratégia 2  Regularizado + Features Temporais  8.106789  11.116326
# 1   Estratégia 1                       Regularizado  8.131163  11.130490
# 3   Estratégia 1  Regularizado + Features Temporais  8.141041  11.155476
# 0   Estratégia 1                            Inicial  8.162475  11.284596
# 6   Estratégia 2       Inicial + Features Temporais  8.144565  11.324878
# 4   Estratégia 2                            Inicial  8.188678  11.361140
# 2   Estratégia 1       Inicial + Features Temporais  8.194339  11.369955
#
#           R2
# ...

# %%
print("Estratégia 1:", xgb_reg_fe_01.best_iteration, xgb_reg_fe_01.best_score)
print("Estratégia 2:", xgb_reg_fe_02.best_iteration, xgb_reg_fe_02.best_score)
print("Estratégia 3:", xgb_reg_fe_03.best_iteration, xgb_reg_fe_03.best_score)
# Out:
# Estratégia 1: 498 11.155476160285922
# Estratégia 2: 479 11.116325726083081
# Estratégia 3: 475 10.704409341678863

# %%
# Inicial + features temporais
y_pred_test_ini_fe_01 = xgb_ini_fe_01.predict(X_test_01_fe)
y_pred_test_ini_fe_02 = xgb_ini_fe_02.predict(X_test_02_fe)
y_pred_test_ini_fe_03 = xgb_ini_fe_03.predict(X_test_03_fe)

resultados_test_ini_fe_01 = avaliar_modelo(y_test_01, y_pred_test_ini_fe_01)
resultados_test_ini_fe_02 = avaliar_modelo(y_test_02, y_pred_test_ini_fe_02)
resultados_test_ini_fe_03 = avaliar_modelo(y_test_03, y_pred_test_ini_fe_03)

# Regularizado + features temporais
y_pred_test_reg_fe_01 = xgb_reg_fe_01.predict(X_test_01_fe)
y_pred_test_reg_fe_02 = xgb_reg_fe_02.predict(X_test_02_fe)
y_pred_test_reg_fe_03 = xgb_reg_fe_03.predict(X_test_03_fe)

resultados_test_reg_fe_01 = avaliar_modelo(y_test_01, y_pred_test_reg_fe_01)
resultados_test_reg_fe_02 = avaliar_modelo(y_test_02, y_pred_test_reg_fe_02)
resultados_test_reg_fe_03 = avaliar_modelo(y_test_03, y_pred_test_reg_fe_03)

# %%
comp_test_all = pd.DataFrame([
    {"estrategia": "Estratégia 1", "modelo": "Inicial", **resultados_test_01},
    {"estrategia": "Estratégia 1", "modelo": "Regularizado", **resultados_test_reg_01},
    {"estrategia": "Estratégia 1", "modelo": "Inicial + Features Temporais", **resultados_test_ini_fe_01},
    {"estrategia": "Estratégia 1", "modelo": "Regularizado + Features Temporais", **resultados_test_reg_fe_01},

    {"estrategia": "Estratégia 2", "modelo": "Inicial", **resultados_test_02},
    {"estrategia": "Estratégia 2", "modelo": "Regularizado", **resultados_test_reg_02},
    {"estrategia": "Estratégia 2", "modelo": "Inicial + Features Temporais", **resultados_test_ini_fe_02},
    {"estrategia": "Estratégia 2", "modelo": "Regularizado + Features Temporais", **resultados_test_reg_fe_02},

    {"estrategia": "Estratégia 3", "modelo": "Inicial", **resultados_test_03},
    {"estrategia": "Estratégia 3", "modelo": "Regularizado", **resultados_test_reg_03},
    {"estrategia": "Estratégia 3", "modelo": "Inicial + Features Temporais", **resultados_test_ini_fe_03},
    {"estrategia": "Estratégia 3", "modelo": "Regularizado + Features Temporais", **resultados_test_reg_fe_03},
])

comp_test_all.sort_values("RMSE")
# Out:
#       estrategia                             modelo       MAE       RMSE  \
# 0   Estratégia 1                            Inicial  7.843688  10.826835
# 2   Estratégia 1       Inicial + Features Temporais  7.821153  10.830801
# 3   Estratégia 1  Regularizado + Features Temporais  7.911754  10.839834
# 11  Estratégia 3  Regularizado + Features Temporais  7.919675  10.859678
# 10  Estratégia 3       Inicial + Features Temporais  7.849791  10.864480
# 1   Estratégia 1                       Regularizado  7.950550  10.869112
# 8   Estratégia 3                            Inicial  7.888167  10.881101
# 9   Estratégia 3                       Regularizado  7.949236  10.892696
# 6   Estratégia 2       Inicial + Features Temporais  7.901522  10.944566
# 7   Estratégia 2  Regularizado + Features Temporais  7.991348  10.960100
# 4   Estratégia 2                            Inicial  7.924267  10.965247
# 5   Estratégia 2                       Regularizado  8.013802  10.979200
#
#           R2
# ...

# %% [markdown]
# ### A adição das novas features temporais,features cíclicas de hora, mês e dia da semana, além de diferenças entre lags de PM2.5, não trouxe ganho consistente de desempenho. Em validação, o melhor modelo permaneceu sendo o XGBoost regularizado da Estratégia 3 sem as novas features. No teste, as diferenças entre os modelos foram pequenas, com leve melhora de MAE em alguns casos, mas sem redução expressiva de RMSE.
#
# ### Assim, as novas features temporais não prejudicaram drasticamente o modelo, mas também não apresentaram ganho suficiente para justificar sua adoção como melhor configuração nesta rodada.

# %% [markdown]
# ## Conclusão

# %% [markdown]
# ## Como as diferenças no teste foram pequenas e a seleção de modelo deve ser baseada na validação, a Estratégia 3 com XGBoost regularizado foi considerada a melhor configuração desta etapa. No entanto, os resultados indicam que as estratégias apresentam desempenho muito próximo, e que novas melhorias devem focar em outros tipos de feature engineering ou tuning mais refinado.
